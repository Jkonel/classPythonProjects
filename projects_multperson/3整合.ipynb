# %%
import pandas as pd
import numpy as np

cc=pd.read_csv('./result_cc++.csv')
hard=pd.read_csv('./result_embeded_hardware.csv')
soft=pd.read_csv('./result_embeded_software.csv')
go=pd.read_csv('./result_go.csv')
java=pd.read_csv('./result_java.csv')
linux=pd.read_csv('./result_linux.csv')
php=pd.read_csv('./result_php.csv')
python=pd.read_csv('./result_python.csv')
jobs=[
    {"c/c++工程师":(len(cc))},
    {"嵌入式硬件工程师":(len(hard))},
    {"嵌入式软件工程师":(len(soft))},
    {"GO开发工程师":(len(go))},
    {"JAVA开发工程师":(len(java))},
    {"Linux开发工程师":(len(linux))},
    {"PHP开发工程师":(len(php))},
    {"python工程师":(len(python))}
    ]
jobs
# Out:
# [{'c/c++工程师': 8536},
#  {'嵌入式硬件工程师': 857},
#  {'嵌入式软件工程师': 6499},
#  {'GO开发工程师': 502},
#  {'JAVA开发工程师': 24689},
#  {'Linux开发工程师': 7370},
#  {'PHP开发工程师': 3033},
#  {'python工程师': 3109}]

# %%
pip install pyecharts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_xaxis(
        [
            "全部职业",
        
        ]
    )
    .add_yaxis("c/c++", [8536],color='blue')
    .add_yaxis("硬件开发", [857],color='green')
    .add_yaxis("软件开发", [6499],color='red')
    .add_yaxis("GO", [502],color='black')
    .add_yaxis("JAVA", [24689],color='pink')
    .add_yaxis("Linux", [7370],color='yellow')    

    .add_yaxis("PHP", [3033],color='orange')
    .add_yaxis("python", [3109],color='purple')
    
    
    
   
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=0)),
        title_opts=opts.TitleOpts(title="此职业岗位总数"),
    )
   
)
c.render_notebook()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3e8451e32fca4cf8a812cee571e299d4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3e8451e32fca4cf8a812cee571e299d4 = echarts.init(
#                     document.getElementById('3e8451e32fca4cf8a812cee571e299d4'), 'white', {renderer: 'canvas'});
#                 var option_3e8451e32fca4cf8a812cee571e299d4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...
