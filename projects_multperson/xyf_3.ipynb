# %%
import pandas as pd
import numpy as np

# %%
cc=pd.read_csv('./cc++_salary_norm_add_provence_city_area_del_none.csv')

cc
# Out:
#              title              company address      salery   date  \
# 0         c++软件工程师          上海唯能炬科技有限公司  上海-宝山区    0.5-1万/月  06-19
# 1       C\C++开发工程师       得实信息科技（深圳）有限公司  深圳-南山区    0.5-1万/月  06-19
# 2          C++软件开发        哈尔滨精达测量仪器有限公司     哈尔滨      6-8千/月  06-19
# 3       C++游戏服务器开发         南京久娱信息技术有限公司  南京-栖霞区    0.7-1万/月  06-19
# 4         C++开发工程师       上海控创信息技术股份有限公司      上海  1.2-1.8万/月  06-19
# ...            ...                  ...     ...         ...    ...
# 36975    Java开发工程师  米思米（中国）精密机械贸易有限公...  上海-静安区      1-2万/月  06-19
# 36976        硬件工程师         深圳市中微泽电子有限公司      深圳    0.8-1万/月  06-19
# 36977   嵌入式软件开发工程师           杭州图软科技有限公司  杭州-余杭区  0.8-1.5万/月  06-19
# 36978  VC++应用软件工程师       深圳市高川自动化技术有限公司  深圳-宝安区    1.5-2万/月  06-19
# 36979      图像算法工程师        武汉迪赛威智能科技有限公司      武汉    1.5-2万/月  06-19
#
#        salary_min  salary_max provence city area
# 0          5000.0     10000.0      上海市   上海  宝山区
# 1          5000.0     10000.0      广东省   深圳  南山区
# ...

# %%
len(cc)
# Out:
# 36980

# %%
# c c++职位总数
cc.shape
# Out:
# (36980, 10)

# %%
hard=pd.read_csv('./embeded_hardware_salary_norm_add_provence_city_area_del_none.csv')
hard
# Out:
#                 title         company     address      salery   date  \
# 0        嵌入式硬件工程师（双休）   武汉中飞扬测控工程有限公司      武汉-黄陂区      6-8千/月  06-19
# 1            嵌入式硬件工程师    钛深科技（深圳）有限公司      成都-高新区  0.8-1.5万/月  06-19
# 2            嵌入式硬件工程师    上海智显光电科技有限公司      上海-闵行区    10-15万/年  06-19
# 3            嵌入式硬件工程师  南京协澳智能控制系统有限公司      南京-鼓楼区      2-3万/月  06-19
# 4    嵌入式硬件工程师（鸿鹄安全公司）   江苏费尔曼安全科技有限公司          徐州      6-8千/月  06-19
# ..                ...             ...         ...         ...    ...
# 865          嵌入式硬件工程师      西安聚能仪器有限公司      西安-未央区  0.4-1.2万/月  06-16
# 866    硬件工程师/嵌入式硬件工程师    西安锦威电子科技有限公司  西安-高新技术...  0.8-1.5万/月  06-16
# 867          嵌入式硬件工程师    上海朝辉压力仪器有限公司      上海-松江区  0.8-1.5万/月  06-19
# 868          嵌入式硬件工程师  广州老店长互联网科技有限公司      广州-番禺区    1-1.5万/月  06-16
# 869          嵌入式硬件工程师     长沙万为机器人有限公司          长沙    1-1.5万/月  06-16
#
#      salary_min  salary_max provence city     area
# 0        6000.0      8000.0      湖北省   武汉      黄陂区
# ...

# %%
# 嵌入式硬件工程师职位总数
hard.shape
# Out:
# (870, 10)

# %%
soft=pd.read_csv('./embeded_software_salary_norm_add_provence_city_area_del_none.csv')
soft
# Out:
#                         title          company  address      salery   date  \
# 0                嵌入式软件工程师（蓝牙）   广州博冠光电科技股份有限公司       广州    1-1.6万/月  06-19
# 1     嵌入式软件工程师（WG1tx）(J12049)   北京东方国信科技股份有限公司       北京      2-4万/月  06-19
# 2                    嵌入式软件工程师    上海英威腾工业技术有限公司       上海    1.5-3万/月  06-19
# 3                    嵌入式软件工程师    合肥英威晟光电科技有限公司   合肥-高新区    1-1.5万/月  06-19
# 4                    嵌入式软件工程师      深圳市勤迈电子有限公司  深圳-龙华新区    1-1.5万/月  06-19
# ...                       ...              ...      ...         ...    ...
# 6722                   嵌入式工程师     武汉四维讯谷科技有限公司   武汉-武昌区  1.2-1.8万/月  05-04
# 6723               嵌入式软件开发工程师     南京凌鸥创芯电子有限公司   南京-栖霞区    0.8-2万/月  05-04
# 6724                   嵌入式工程师       武汉鼎深科技有限公司   武汉-硚口区  0.8-1.8万/月  05-03
# 6725               嵌入式软件开发工程师   湖南波尔坤雷信息科技有限公司       长沙  0.8-1.2万/月  05-03
# 6726                 嵌入式开发工程师  石家庄市安瑞尔机械制造有限公司      石家庄      4-6千/月  05-03
#
#       salary_min  salary_max provence city  area
# ...

# %%
# 嵌入式软件工程师职位总数
soft.shape
# Out:
# (6727, 10)

# %%
go=pd.read_csv('./go_salary_norm_add_provence_city_area_del_none.csv')
go
# Out:
#                                 title              company  address  \
# 0                             go服务器开发                 DeNA       上海
# 1                           Go语言高级架构师       凯睿管理咨询（广州）有限公司       深圳
# 2                             GO开发工程师         北京数猎天下科技有限公司   北京-海淀区
# 3                            GO 后端工程师         云南升玥信息技术有限公司   昆明-西山区
# 4                             GO服务器开发  蝴蝶互动（上海）信息技术有限公司...  上海-浦东新区
# ...                               ...                  ...      ...
# 3703  etime implementation consultant            ADP China  上海-浦东新区
# 3704          Vendor Relation Manager         南京摩睿信息技术有限公司       南京
# 3705               Field Manager 区域经理           汇丰人寿保险有限公司  上海-浦东新区
# 3706   Private Wealth Planner 私人财富规划师           汇丰人寿保险有限公司  上海-浦东新区
# 3707          Java (angular 2+) 开发工程师      奥解思信息技术（上海）有限公司  上海-浦东新区
#
#           salery   date  salary_min  salary_max provence city  area
# 0       1-1.5万/月  06-19     10000.0     15000.0      上海市   上海   NaN
# ...

# %%
# go 服务器开发职位总数
go.shape
# Out:
# (3708, 10)

# %%
java=pd.read_csv('./java_salary_norm_add_provence_city_area_del_none.csv')
java
# Out:
#                     title        company  address      salery   date  \
# 0               Java开发工程师      三一重工重起事业部       长沙    1-2.5万/月  06-19
# 1             研发工程师（java）       源氏木语家具集团   上海-松江区      1-2万/月  06-19
# 2             Java高级开发工程师  深圳车友援信息技术有限公司   深圳-南山区    1.5-3万/月  06-19
# 3             高级java开发工程师  河南云之谷信息科技有限公司  郑州-郑东新区    0.8-1万/月  06-19
# 4             Java高级开发工程师     杭州尤普软件有限公司   杭州-拱墅区    2-2.5万/月  06-19
# ...                   ...            ...      ...         ...    ...
# 57970     交付经理 (MJ000646)  京北方信息技术股份有限公司  上海-浦东新区  2.5-3.5万/月  06-17
# 57971               工作站博士  京北方信息技术股份有限公司   北京-海淀区      5-7万/月  06-17
# 57972        系统架构师（微服务方向）  京北方信息技术股份有限公司   北京-海淀区  2.5-3.5万/月  06-17
# 57973       架构师（云计算大数据方向）  京北方信息技术股份有限公司   北京-海淀区  2.5-3.5万/月  06-17
# 57974  全栈开发工程师 (MJ000657)  京北方信息技术股份有限公司  上海-浦东新区    1.5-2万/月  06-17
#
#        salary_min  salary_max provence city  area
# 0         10000.0     25000.0      湖南省   长沙   NaN
# ...

# %%
# java工程师职位总数
java.shape
# Out:
# (57975, 10)

# %%
linux=pd.read_csv('./linux_salary_norm_add_provence_city_area_del_none.csv')
linux
# Out:
#                 title          company address      salery   date  salary_min  \
# 0       嵌入式Linux开发工程师    深圳市安车检测股份有限公司      泰安  0.6-1.2万/月  06-19      6000.0
# 1          Linux软件工程师      深圳市天双科技有限公司  深圳-南山区    1-1.5万/月  06-19     10000.0
# 2       Linux前后端开发工程师     湖南麒麟信安科技有限公司  长沙-岳麓区  0.8-1.5万/月  06-19      8000.0
# 3          linux系统工程师   国和瑞斯（北京）科技有限公司  北京-海淀区    0.8-1万/月  06-19      8000.0
# 4      Linux设备驱动开发工程师        无锡先进技术研究院  无锡-滨湖区    20-25万/年  06-19     16666.0
# ...               ...              ...     ...         ...    ...         ...
# 55458   高级软件工程师/软件工程师  伟易达电子产品（深圳）有限公司  深圳-南山区    1-1.5万/月  06-12     10000.0
# 55459         软件开发工程师  伟易达电子产品（深圳）有限公司  深圳-南山区    1-1.5万/月  06-12     10000.0
# 55460       Java开发工程师    东莞市诺丽电子科技有限公司      东莞  0.9-1.6万/月  06-12      9000.0
# 55461       信息系统集成工程师   广东兆邦智能科技股份有限公司  珠海-香洲区    0.5-1万/月  06-12      5000.0
# 55462       Java开发工程师  上海易立德信息技术股份有限公司  佛山-顺德区  1.2-1.5万/月  06-12     12000.0
#
# ...

# %%
# linux工程师职位总数
linux.shape
# Out:
# (55463, 10)

# %%
php=pd.read_csv('./php_salary_norm_add_provence_city_area_del_none.csv')
php
# Out:
#                     title          company address      salery   date  \
# 0     PHP开发工程师（2020届校园招聘）     青木数字技术股份有限公司      广州      5-8千/月  06-19
# 1                PHP开发工程师  中盛业（山东）智能科技有限公司  济南-槐荫区  0.7-1.2万/月  06-19
# 2              PHP高级开发工程师      惠州市一匠科技有限公司      惠州    1-1.5万/月  06-19
# 3       PHP高级开发（15-25K汉口）              博看网  武汉-江汉区  1.5-2.5万/月  06-19
# 4                PHP开发工程师    武汉泰乐奇信息科技有限公司  武汉-洪山区    1-1.5万/月  06-19
# ...                   ...              ...     ...         ...    ...
# 9059                软件工程师     江西坚强百货连锁有限公司      赣州    0.8-1万/月  06-02
# 9060              前端开发工程师       上海鉴崧实业有限公司  上海-松江区    0.8-1万/月  06-02
# 9061                开发工程师   阳光麦田贸易（深圳）有限公司      深圳    1.5-2万/月  06-02
# 9062              前端开发工程师   同蒙信息技术（苏州）有限公司      南京  0.8-1.5万/月  06-02
# 9063             C++开发工程师   南京网格天地软件技术有限公司  南京-玄武区    0.6-1万/月  06-02
#
#       salary_min  salary_max provence city area
# 0         5000.0      8000.0      广东省   广州  NaN
# ...

# %%
# php开发工程师职位总数
php.shape
# Out:
# (9064, 10)

# %%
python=pd.read_csv('./python_salary_norm_add_provence_city_area_del_none.csv')
python
# Out:
#                             title              company  address      salery  \
# 0                     python软件工程师         浙江大立科技股份有限公司   杭州-滨江区  0.8-1.5万/月
# 1                 Python开发工程师-世纪福              科技城人才市场       苏州      1-2万/月
# 2                     Python开发工程师       陕西云智汇谷创新科技有限公司   西安-碑林区      6-8千/月
# 3                      python开发经理            朗森特科技有限公司   上海-徐汇区  1.5-2.2万/月
# 4                   python后端开发工程师        苏州奇梦者网络科技有限公司  苏州-工业园区    1-1.5万/月
# ...                           ...                  ...      ...         ...
# 28243  Windows C/C++ 初级软件工程师（应届生）           格尔软件股份有限公司   上海-静安区    1-1.5万/月
# 28244            运维工程师 (MJ002066)  神州数码系统集成服务有限公司深圳...   长沙-芙蓉区      4-6千/月
# 28245                        生信总监        广州市香雪制药股份有限公司   广州-白云区    1.2-2万/月
# 28246                     后端开发工程师         上海优梦信息科技有限公司   上海-杨浦区    1.5-2万/月
# 28247                    大数据开发工程师         上海走起网络科技有限公司   上海-长宁区    1-1.5万/月
#
#         date  salary_min  salary_max provence city  area
# ...

# %%
# python开发工程师职位总数
python.shape
# Out:
# (28248, 10)

# %%
import pandas as pd

jobs=[
    {"c/c++工程师":(len(cc))},
    {"嵌入式硬件工程师":(len(hard))},
    {"嵌入式软件工程师":(len(soft))},
    {"GO开发工程师":(len(go))},
    {"JAVA开发工程师":(len(java))},
    {"Linux开发工程师":(len(linux))},
    {"PHP开发工程师":(len(php))},
    {"python工程师":(len(python))}
    ]
jobs
# Out:
# [{'c/c++工程师': 36980},
#  {'嵌入式硬件工程师': 870},
#  {'嵌入式软件工程师': 6727},
#  {'GO开发工程师': 3708},
#  {'JAVA开发工程师': 57975},
#  {'Linux开发工程师': 55463},
#  {'PHP开发工程师': 9064},
#  {'python工程师': 28248}]

# %%
pip install pyecharts
# Out:
# ...
#   Using cached pyecharts-1.8.1-py3-none-any.whl (134 kB)
# ...
#   Using cached prettytable-0.7.2.tar.bz2 (21 kB)
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13704 sha256=b8ee48a5d6909065e13a9eaa100295298da3ee5d89ff7758bb2b58f206324d96
#   Stored in directory: c:\users\jkonel.000\appdata\local\pip\cache\wheels\8c\76\0b\eb9eb3da7e2335e3577e3f96a0ae9f74f206e26457bd1a2bc8
# Successfully built prettytable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002812E6EBC88>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyecharts/
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

c = (
    Bar()
    .add_xaxis(
        [
            "全部职业",
        ]
    )
    .add_yaxis("c/c++", [36980],color='blue')
    .add_yaxis("硬件开发", [870],color='green')
    .add_yaxis("软件开发", [6727],color='red')
    .add_yaxis("GO", [3708],color='black')
    .add_yaxis("JAVA", [57975],color='pink')
    .add_yaxis("Linux", [55463],color='yellow')    

            .add_yaxis("PHP", [9064],color='orange')
    .add_yaxis("python", [28248],color='purple')
    
    
    
   
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=0)),
        title_opts=opts.TitleOpts(title="此职业岗位总数"),
    )
    #.render("bar_rotate_xaxis_label.html")
)

c.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-827362b88bda> in <module>
# ----> 1 from pyecharts import options as opts
#       2 from pyecharts.charts import Bar
#       3
#       4 c = (
#       5     Bar()
#
# ModuleNotFoundError: No module named 'pyecharts'
